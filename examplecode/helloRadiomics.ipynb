# %% [markdown]
# imports

# %%
import logging
import os

import radiomics
from radiomics import featureextractor, getFeatureClasses

# %% [markdown]
# setting up log files

# %%
# Get the PyRadiomics logger (default log-level = INFO)
logger = radiomics.logger
logger.setLevel(logging.DEBUG)  # set level to DEBUG to include debug log messages in log file

# Write out all log entries to a file
handler = logging.FileHandler(filename='testLog.txt', mode='w')
formatter = logging.Formatter('%(levelname)s:%(name)s: %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# %%
featureClasses = getFeatureClasses()
#imageName, maskName = radiomics.getTestCase('brain1')
imageName = "../data/image/image_1.nii.gz"
maskName  = "../data/mask/mask_1.nii.gz"


if imageName is None or maskName is None:  # Something went wrong, in this case PyRadiomics will also log an error
    msg = 'Error getting testcase!'
    raise Exception(msg)  # Raise exception to prevent cells below from running in case of "run all"

# %%
# Use a parameter file, this customizes the extraction settings and also specifies the input image types to use and which features should be extracted
params = "../params/Params.yaml"

extractor = featureextractor.RadiomicsFeatureExtractor(params)

# %%
# Alternative: use hardcoded settings (separate for settings, input image types and enabled features)
settings = {}
settings['binWidth'] = 25
settings['resampledPixelSpacing'] = None
# settings['resampledPixelSpacing'] = [3, 3, 3]  # This is an example for defining resampling (voxels with size 3x3x3mm)
settings['interpolator'] = 'sitkBSpline'
settings['verbose'] = True

extractor = featureextractor.RadiomicsFeatureExtractor(**settings)

# %%
# By default, only 'Original' (no filter applied) is enabled. Optionally enable some image types:

# extractor.enableImageTypeByName('Wavelet')
# extractor.enableImageTypeByName('LoG', customArgs={'sigma':[3.0]})
# extractor.enableImageTypeByName('Square')
# extractor.enableImageTypeByName('SquareRoot')
# extractor.enableImageTypeByName('Exponential')
# extractor.enableImageTypeByName('Logarithm')

# Alternative; set filters in one operation 
# This updates current enabled image types, i.e. overwrites custom settings specified per filter. 
# However, image types already enabled, but not passed in this call, are not disabled or altered.

# extractor.enableImageTypes(Wavelet={}, LoG={'sigma':[3.0]})

print('Enabled input images:')
for imageType in extractor.enabledImagetypes:
    print('\t' + imageType)
# Out:
# Enabled input images:
# 	Original

# %%
print('Calculating features')
featureVector = extractor.execute(imageName, maskName)
# Out:
# Calculating features
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 print('Calculating features')
# ----> 2 featureVector = extractor.execute(imageName, maskName)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/radiomics/featureextractor.py:272, in RadiomicsFeatureExtractor.execute(self, imageFilepath, maskFilepath, label, label_channel, voxelBased)
#     270 # 1. Load the image and mask
#     271 featureVector = collections.OrderedDict()
# --> 272 image, mask = self.loadImage(imageFilepath, maskFilepath, generalInfo, **_settings)
#     274 # 2. Check whether loaded mask contains a valid ROI for feature extraction and get bounding box
#     275 # Raises a ValueError if the ROI is invalid
#     276 boundingBox, correctedMask = imageoperations.checkMask(image, mask, **_settings)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/radiomics/featureextractor.py:375, in RadiomicsFeatureExtractor.loadImage(ImageFilePath, MaskFilePath, generalInfo, **kwargs)
#     373   image = ImageFilePath
#     374 else:
# --> 375   raise ValueError('Error reading image Filepath or SimpleITK object')
#     377 if isinstance(MaskFilePath, six.string_types) and os.path.isfile(MaskFilePath):
#     378   mask = sitk.ReadImage(MaskFilePath)
#
# ValueError: Error reading image Filepath or SimpleITK object

# %%
# Show output
for featureName in featureVector:
    print(f'Computed {featureName}: {featureVector[featureName]}')
# Out:
# Computed diagnostics_Versions_PyRadiomics: v3.0.1
# Computed diagnostics_Versions_Numpy: 1.25.1
# Computed diagnostics_Versions_SimpleITK: 2.5.3
# Computed diagnostics_Versions_PyWavelet: 1.8.0
# Computed diagnostics_Versions_Python: 3.11.4
# Computed diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'verbose': True}
# Computed diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# Computed diagnostics_Image-original_Hash: 5c9ce3ca174f0f8324aa4d277e0fef82dc5ac566
# Computed diagnostics_Image-original_Dimensionality: 3D
# Computed diagnostics_Image-original_Spacing: (0.7812499999999999, 0.7812499999999999, 6.499999999999998)
# Computed diagnostics_Image-original_Size: (256, 256, 25)
# Computed diagnostics_Image-original_Mean: 385.6564080810547
# Computed diagnostics_Image-original_Minimum: 0.0
# Computed diagnostics_Image-original_Maximum: 3057.0
# Computed diagnostics_Mask-original_Hash: 9dc2c3137b31fd872997d92c9a92d5178126d9d3
# Computed diagnostics_Mask-original_Spacing: (0.7812499999999999, 0.7812499999999999, 6.499999999999998)
# Computed diagnostics_Mask-original_Size: (256, 256, 25)
# Computed diagnostics_Mask-original_BoundingBox: (162, 84, 11, 47, 70, 7)
# Computed diagnostics_Mask-original_VoxelNum: 4137
# Computed diagnostics_Mask-original_VolumeNum: 2
# Computed diagnostics_Mask-original_CenterOfMassIndex: (186.98549673676578, 106.3562968334542, 14.38917089678511)
# Computed diagnostics_Mask-original_CenterOfMass: (46.47304432559825, 16.518518098863908, 15.529610829103234)
# Computed original_shape_Elongation: 0.5621171627174116
# Computed original_shape_Flatness: 0.46105975346582595
# Computed original_shape_LeastAxisLength: 28.584423185376497
# Computed original_shape_MajorAxisLength: 61.997220469808795
# Computed original_shape_Maximum2DDiameterColumn: 49.490854979101925
# Computed original_shape_Maximum2DDiameterRow: 65.88905951721043
# Computed original_shape_Maximum2DDiameterSlice: 53.59397776919529
# Computed original_shape_Maximum3DDiameter: 69.60099030590368
# Computed original_shape_MeshVolume: 16147.511800130298
# Computed original_shape_MinorAxisLength: 34.849701666854756
# Computed original_shape_Sphericity: 0.47982345362314927
# Computed original_shape_SurfaceArea: 6438.821603779402
# Computed original_shape_SurfaceVolumeRatio: 0.3987500788652432
# Computed original_shape_VoxelVolume: 16412.658691406243
# Computed original_firstorder_10Percentile: 632.0
# Computed original_firstorder_90Percentile: 1044.4
# Computed original_firstorder_Energy: 2918821481.0
# Computed original_firstorder_Entropy: 4.601935553903786
# Computed original_firstorder_InterquartileRange: 253.0
# Computed original_firstorder_Kurtosis: 2.1807729393860265
# Computed original_firstorder_Maximum: 1266.0
# Computed original_firstorder_MeanAbsoluteDeviation: 133.44726195252767
# Computed original_firstorder_Mean: 825.2354363065023
# Computed original_firstorder_Median: 812.0
# Computed original_firstorder_Minimum: 468.0
# Computed original_firstorder_Range: 798.0
# Computed original_firstorder_RobustMeanAbsoluteDeviation: 103.00138343026683
# Computed original_firstorder_RootMeanSquared: 839.9646448180755
# Computed original_firstorder_Skewness: 0.27565085908587594
# Computed original_firstorder_TotalEnergy: 11579797135.314934
# Computed original_firstorder_Uniformity: 0.045156963555862184
# Computed original_firstorder_Variance: 24527.07920837261
# Computed original_glcm_Autocorrelation: 289.5436994017259
# Computed original_glcm_ClusterProminence: 27995.937591943148
# Computed original_glcm_ClusterShade: 19.605083427286676
# Computed original_glcm_ClusterTendency: 108.73139325453903
# Computed original_glcm_Contrast: 47.492125114429776
# Computed original_glcm_Correlation: 0.3917522006696661
# Computed original_glcm_DifferenceAverage: 5.284468789866316
# Computed original_glcm_DifferenceEntropy: 3.74406097806642
# Computed original_glcm_DifferenceVariance: 16.65563705027098
# Computed original_glcm_Id: 0.28722572382985156
# Computed original_glcm_Idm: 0.20022255640475703
# Computed original_glcm_Idmn: 0.961402169623227
# Computed original_glcm_Idn: 0.8726052157397169
# Computed original_glcm_Imc1: -0.09438938808738298
# Computed original_glcm_Imc2: 0.6942249020670357
# Computed original_glcm_InverseVariance: 0.19881884197093194
# Computed original_glcm_JointAverage: 16.55380772442751
# Computed original_glcm_JointEnergy: 0.002893149242988865
# Computed original_glcm_JointEntropy: 8.799696270248813
# Computed original_glcm_MCC: 0.4990404679585558
# Computed original_glcm_MaximumProbability: 0.007352392266290182
# Computed original_glcm_SumAverage: 33.10761544885502
# Computed original_glcm_SumEntropy: 5.354241321485615
# Computed original_glcm_SumSquares: 39.05587959224222
# Computed original_gldm_DependenceEntropy: 6.885019899269458
# Computed original_gldm_DependenceNonUniformity: 936.6601401982113
# Computed original_gldm_DependenceNonUniformityNormalized: 0.22641047623838803
# Computed original_gldm_DependenceVariance: 2.1619872286911965
# Computed original_gldm_GrayLevelNonUniformity: 186.8143582306019
# Computed original_gldm_GrayLevelVariance: 39.19271419906397
# Computed original_gldm_HighGrayLevelEmphasis: 280.4065748126662
# Computed original_gldm_LargeDependenceEmphasis: 8.661590524534686
# Computed original_gldm_LargeDependenceHighGrayLevelEmphasis: 2335.0519700265895
# Computed original_gldm_LargeDependenceLowGrayLevelEmphasis: 0.07650590736710827
# Computed original_gldm_LowGrayLevelEmphasis: 0.00860027409479837
# Computed original_gldm_SmallDependenceEmphasis: 0.37960167130711403
# Computed original_gldm_SmallDependenceHighGrayLevelEmphasis: 110.30563945728201
# Computed original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.0035453562622343696
# Computed original_glrlm_GrayLevelNonUniformity: 175.6351923150419
# Computed original_glrlm_GrayLevelNonUniformityNormalized: 0.04514123814981055
# Computed original_glrlm_GrayLevelVariance: 39.118151021979244
# Computed original_glrlm_HighGrayLevelRunEmphasis: 281.066493908972
# Computed original_glrlm_LongRunEmphasis: 1.2268440382584342
# Computed original_glrlm_LongRunHighGrayLevelEmphasis: 341.2865790983503
# Computed original_glrlm_LongRunLowGrayLevelEmphasis: 0.010601170478748765
# Computed original_glrlm_LowGrayLevelRunEmphasis: 0.008600397891661503
# Computed original_glrlm_RunEntropy: 4.915038003159503
# Computed original_glrlm_RunLengthNonUniformity: 3500.0432315746298
# Computed original_glrlm_RunLengthNonUniformityNormalized: 0.8950494659480998
# Computed original_glrlm_RunPercentage: 0.9404064632491029
# Computed original_glrlm_RunVariance: 0.08479457789590625
# Computed original_glrlm_ShortRunEmphasis: 0.9559391731405504
# Computed original_glrlm_ShortRunHighGrayLevelEmphasis: 268.9741798411307
# Computed original_glrlm_ShortRunLowGrayLevelEmphasis: 0.008229766244155428
# Computed original_glszm_GrayLevelNonUniformity: 82.38716577540107
# Computed original_glszm_GrayLevelNonUniformityNormalized: 0.044057307901283996
# Computed original_glszm_GrayLevelVariance: 40.60313992393263
# Computed original_glszm_HighGrayLevelZoneEmphasis: 288.6235294117647
# Computed original_glszm_LargeAreaEmphasis: 13.615508021390374
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis: 3514.7614973262034
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis: 0.12723841553344326
# Computed original_glszm_LowGrayLevelZoneEmphasis: 0.009100942027706215
# Computed original_glszm_SizeZoneNonUniformity: 747.5967914438503
# Computed original_glszm_SizeZoneNonUniformityNormalized: 0.3997843804512568
# Computed original_glszm_SmallAreaEmphasis: 0.6564478999587141
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis: 193.438051925864
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis: 0.006416982055097711
# Computed original_glszm_ZoneEntropy: 6.5082149861981895
# Computed original_glszm_ZonePercentage: 0.4520183708000967
# Computed original_glszm_ZoneVariance: 8.721239097486347
# Computed original_ngtdm_Busyness: 1.4467306835644076
# Computed original_ngtdm_Coarseness: 0.001712035271356631
# Computed original_ngtdm_Complexity: 1439.5127782445836
# Computed original_ngtdm_Contrast: 0.24786529128414
# Computed original_ngtdm_Strength: 0.6307314827348611
