# %% [markdown]
# imports

# %%
import logging
import os

import radiomics
from radiomics import featureextractor, getFeatureClasses
from skimage.measure import marching_cubes

# %% [markdown]
# setting up log files

# %%
# Get the PyRadiomics logger (default log-level = INFO)
logger = radiomics.logger
logger.setLevel(logging.DEBUG)  # set level to DEBUG to include debug log messages in log file

# Write out all log entries to a file
handler = logging.FileHandler(filename='testLog.txt', mode='w')
formatter = logging.Formatter('%(levelname)s:%(name)s: %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# %%
featureClasses = getFeatureClasses()
#imageName, maskName = radiomics.getTestCase('brain1')
imageName = "../data/images/image_1.nii.gz"
maskName  = "../data/masks/mask_1.nii.gz"


if imageName is None or maskName is None:  # Something went wrong, in this case PyRadiomics will also log an error
    msg = 'Error getting testcase!'
    raise Exception(msg)  # Raise exception to prevent cells below from running in case of "run all"

# %% [markdown]
# debug for file locations

# %%
#import SimpleITK as sitk

#img = sitk.ReadImage(imageName)
#msk = sitk.ReadImage(maskName)

#print("Image size:", img.GetSize(), "pixel:", img.GetPixelIDTypeAsString())
#print("Mask  size:", msk.GetSize(), "pixel:", msk.GetPixelIDTypeAsString())

# %%
# Use a parameter file, this customizes the extraction settings and also specifies the input image types to use and which features should be extracted
params = "../params/Params.yaml"

extractor = featureextractor.RadiomicsFeatureExtractor(params)

# %%
# Alternative: use hardcoded settings (separate for settings, input image types and enabled features)
settings = {}
settings['binWidth'] = 25
settings['resampledPixelSpacing'] = None
# settings['resampledPixelSpacing'] = [3, 3, 3]  # This is an example for defining resampling (voxels with size 3x3x3mm)
settings['interpolator'] = 'sitkBSpline'
settings['verbose'] = True

extractor = featureextractor.RadiomicsFeatureExtractor(**settings)

# %%
# By default, only 'Original' (no filter applied) is enabled. Optionally enable some image types:

# extractor.enableImageTypeByName('Wavelet')
# extractor.enableImageTypeByName('LoG', customArgs={'sigma':[3.0]})
# extractor.enableImageTypeByName('Square')
# extractor.enableImageTypeByName('SquareRoot')
# extractor.enableImageTypeByName('Exponential')
# extractor.enableImageTypeByName('Logarithm')

# Alternative; set filters in one operation 
# This updates current enabled image types, i.e. overwrites custom settings specified per filter. 
# However, image types already enabled, but not passed in this call, are not disabled or altered.

# extractor.enableImageTypes(Wavelet={}, LoG={'sigma':[3.0]})

print('Enabled input images:')
for imageType in extractor.enabledImagetypes:
    print('\t' + imageType)
# Out:
# Enabled input images:
# 	Original

# %%
print('Calculating features')
featureVector = extractor.execute(imageName, maskName)
# Out:
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
# Show output
for featureName in featureVector:
    print(f'Computed {featureName}: {featureVector[featureName]}')
# Out:
# Computed diagnostics_Versions_PyRadiomics: v3.0.1
# Computed diagnostics_Versions_Numpy: 1.25.1
# Computed diagnostics_Versions_SimpleITK: 2.5.3
# Computed diagnostics_Versions_PyWavelet: 1.8.0
# Computed diagnostics_Versions_Python: 3.11.4
# Computed diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'verbose': True}
# Computed diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# Computed diagnostics_Image-original_Hash: 09f25aca6fb2a884e3eee17fb5272e66202e5430
# Computed diagnostics_Image-original_Dimensionality: 3D
# Computed diagnostics_Image-original_Spacing: (0.859375, 0.859375, 1.0)
# Computed diagnostics_Image-original_Size: (512, 512, 240)
# Computed diagnostics_Image-original_Mean: -683.7469638824463
# Computed diagnostics_Image-original_Minimum: -1024.0
# Computed diagnostics_Image-original_Maximum: 2421.0
# Computed diagnostics_Mask-original_Hash: 0d3a9d25e3d0c02fee305b98b016c846af1d7e39
# Computed diagnostics_Mask-original_Spacing: (0.859375, 0.859375, 1.0)
# Computed diagnostics_Mask-original_Size: (512, 512, 240)
# Computed diagnostics_Mask-original_BoundingBox: (192, 219, 99, 162, 70, 71)
# Computed diagnostics_Mask-original_VoxelNum: 78329
# Computed diagnostics_Mask-original_VolumeNum: 1
# Computed diagnostics_Mask-original_CenterOfMassIndex: (275.3767825454174, 257.6596407460838, 130.45542519373413)
# Computed diagnostics_Mask-original_CenterOfMass: (236.6519224999681, -221.4262537661658, -130.45542519373413)
# Computed original_shape_Elongation: 0.3146662229196935
# Computed original_shape_Flatness: 0.23264227333622287
# Computed original_shape_LeastAxisLength: 35.31635801684222
# Computed original_shape_MajorAxisLength: 151.80542001410794
# Computed original_shape_Maximum2DDiameterColumn: 139.0651553468396
# Computed original_shape_Maximum2DDiameterRow: 56.76242292441365
# Computed original_shape_Maximum2DDiameterSlice: 108.22667275358926
# Computed original_shape_Maximum3DDiameter: 148.2608191931115
# Computed original_shape_MeshVolume: 57661.1083984375
# Computed original_shape_MinorAxisLength: 47.76803813457699
# Computed original_shape_Sphericity: 0.311354429584213
# Computed original_shape_SurfaceArea: 23182.008818461323
# Computed original_shape_SurfaceVolumeRatio: 0.40203890390510616
# Computed original_shape_VoxelVolume: 57847.955322265625
# Computed original_firstorder_10Percentile: 69.0
# Computed original_firstorder_90Percentile: 131.0
# Computed original_firstorder_Energy: 898472245.0
# Computed original_firstorder_Entropy: 2.119133653904939
# Computed original_firstorder_InterquartileRange: 27.0
# Computed original_firstorder_Kurtosis: 9.352375719025702
# Computed original_firstorder_Maximum: 245.0
# Computed original_firstorder_MeanAbsoluteDeviation: 20.900749147072194
# Computed original_firstorder_Mean: 102.55676697008771
# Computed original_firstorder_Median: 108.0
# Computed original_firstorder_Minimum: -111.0
# Computed original_firstorder_Range: 356.0
# Computed original_firstorder_RobustMeanAbsoluteDeviation: 11.965235632027799
# Computed original_firstorder_RootMeanSquared: 107.10038741628483
# Computed original_firstorder_Skewness: -1.9381998368354292
# Computed original_firstorder_TotalEnergy: 663544565.7043457
# Computed original_firstorder_Uniformity: 0.3106666288745996
# Computed original_firstorder_Variance: 952.6025333614309
# Computed original_glcm_Autocorrelation: 95.31494614950046
# Computed original_glcm_ClusterProminence: 164.61075731116594
# Computed original_glcm_ClusterShade: -15.635755824595357
# Computed original_glcm_ClusterTendency: 3.940009844831702
# Computed original_glcm_Contrast: 1.068548139645862
# Computed original_glcm_Correlation: 0.5699563771791223
# Computed original_glcm_DifferenceAverage: 0.693313674923307
# Computed original_glcm_DifferenceEntropy: 1.4821292326650601
# Computed original_glcm_DifferenceVariance: 0.5791140036064294
# Computed original_glcm_Id: 0.7034251782363765
# Computed original_glcm_Idm: 0.6888109004359261
# Computed original_glcm_Idmn: 0.9953658591485885
# Computed original_glcm_Idn: 0.9579737007330759
# Computed original_glcm_Imc1: -0.12343494887781449
# Computed original_glcm_Imc2: 0.5998807859795782
# Computed original_glcm_InverseVariance: 0.4683329758243716
# Computed original_glcm_JointAverage: 9.726065117289904
# Computed original_glcm_JointEnergy: 0.13485073272170905
# Computed original_glcm_JointEntropy: 3.71439400168781
# Computed original_glcm_MCC: 0.6353546490914155
# Computed original_glcm_MaximumProbability: 0.2936267100548774
# Computed original_glcm_SumAverage: 19.45213023457981
# Computed original_glcm_SumEntropy: 2.7448305606890955
# Computed original_glcm_SumSquares: 1.252139496119391
# Computed original_gldm_DependenceEntropy: 6.105407678190714
# Computed original_gldm_DependenceNonUniformity: 3756.6131190236056
# Computed original_gldm_DependenceNonUniformityNormalized: 0.047959416295670895
# Computed original_gldm_DependenceVariance: 32.10551367867351
# Computed original_gldm_GrayLevelNonUniformity: 24334.20637311851
# Computed original_gldm_GrayLevelVariance: 1.6041153551059157
# Computed original_gldm_HighGrayLevelEmphasis: 94.18463149025266
# Computed original_gldm_LargeDependenceEmphasis: 158.11874273896004
# Computed original_gldm_LargeDependenceHighGrayLevelEmphasis: 15623.104622808922
# Computed original_gldm_LargeDependenceLowGrayLevelEmphasis: 1.6388175583286
# Computed original_gldm_LowGrayLevelEmphasis: 0.012038207280347147
# Computed original_gldm_SmallDependenceEmphasis: 0.0427191876217205
# Computed original_gldm_SmallDependenceHighGrayLevelEmphasis: 3.351926720648168
# Computed original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.0008906833971741812
# Computed original_glrlm_GrayLevelNonUniformity: 11563.931881166605
# Computed original_glrlm_GrayLevelNonUniformityNormalized: 0.24307961796103122
# Computed original_glrlm_GrayLevelVariance: 2.1631807954522997
# Computed original_glrlm_HighGrayLevelRunEmphasis: 91.80694451780893
# Computed original_glrlm_LongRunEmphasis: 4.320633409462465
# Computed original_glrlm_LongRunHighGrayLevelEmphasis: 418.54911115012237
# Computed original_glrlm_LongRunLowGrayLevelEmphasis: 0.04776762362714619
# Computed original_glrlm_LowGrayLevelRunEmphasis: 0.012938527522148571
# Computed original_glrlm_RunEntropy: 3.8703851608481648
# Computed original_glrlm_RunLengthNonUniformity: 22698.769987707175
# Computed original_glrlm_RunLengthNonUniformityNormalized: 0.4732283736255645
# Computed original_glrlm_RunPercentage: 0.6067091763832435
# Computed original_glrlm_RunVariance: 1.5355582832894294
# Computed original_glrlm_ShortRunEmphasis: 0.7121548217422814
# Computed original_glrlm_ShortRunHighGrayLevelEmphasis: 63.90852937014361
# Computed original_glrlm_ShortRunLowGrayLevelEmphasis: 0.009788651485157786
# Computed original_glszm_GrayLevelNonUniformity: 339.19578420864593
# Computed original_glszm_GrayLevelNonUniformityNormalized: 0.12118463172870524
# Computed original_glszm_GrayLevelVariance: 6.845544924238623
# Computed original_glszm_HighGrayLevelZoneEmphasis: 71.86709539121115
# Computed original_glszm_LargeAreaEmphasis: 627346.6027152555
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis: 61472120.55519828
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis: 6456.542862030434
# Computed original_glszm_LowGrayLevelZoneEmphasis: 0.024812964653433075
# Computed original_glszm_SizeZoneNonUniformity: 821.183637013219
# Computed original_glszm_SizeZoneNonUniformityNormalized: 0.29338465059421903
# Computed original_glszm_SmallAreaEmphasis: 0.5563793469946438
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis: 40.144038713578055
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis: 0.01480282290519882
# Computed original_glszm_ZoneEntropy: 5.8037033538468945
# Computed original_glszm_ZonePercentage: 0.03573389166209195
# Computed original_glszm_ZoneVariance: 626563.4627864978
# Computed original_ngtdm_Busyness: 39.93676512374137
# Computed original_ngtdm_Coarseness: 0.00010899588632719731
# Computed original_ngtdm_Complexity: 56.73218100316469
# Computed original_ngtdm_Contrast: 0.00800270898124249
# Computed original_ngtdm_Strength: 0.016744317616209592
